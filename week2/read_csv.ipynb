# %% [markdown]
# <a href="https://colab.research.google.com/github/jiangenhe/insc-486-2021-spring/blob/main/week2/read_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read txt File

# %%
path = 'drive/MyDrive/insc486/temp.txt'

# %%
f = open(path)

# %%
lines = [x.rstrip() for x in f]

# %%
lines

# %%
f.close()

# %%
with open(path) as f:
  lines = [x.rstrip() for x in f]
lines

# %% [markdown]
# **Python file modes**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Write file

# %%
with open('tmp.txt', 'w') as handle:
  handle.writelines(x for x in open(path) if len(x) > 1)

# %% [markdown]
# # Read csv File

# %% [markdown]
# ## import csv

# %% [markdown]
# ## Average MPG

# %% [markdown]
# ## The numbers of cylinders

# %% [markdown]
# ## Aggregated data

# %% [markdown]
# Average city mpg for each number of cylinders

# %% [markdown]
# Average number of cylinders of the cars made by each manufacturer

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# 1. Create a list with the average hwy mpg for each class of vehicle in mpg.csv dataset and sort the result from lowest average hwy mpg to highest.

# %% [markdown]
# 2. Find the manufacturer that made the most cars with 8 cylinders
